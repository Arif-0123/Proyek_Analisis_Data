# %% [markdown]
# <a href="https://colab.research.google.com/github/Arif-0123/Proyek_Analisis_Data/blob/main/Air%20Quality%20Dataset/submision/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - Nama: Arif Hidayat
# - Email: a.gaul0812@gmail.com
# - Id Dicoding: kurokyshi

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1.   Bagaimana rata-rata kualitas udara disetiap station dalam beberapa tahun terakhir?
# 2.   station manakah rata-rata kualitas udara terbaik dan terburuk berada?

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### menampilkan semua dataset

# %%
Aotizhongxin_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
Aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
Changping_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Changping_20130301-20170228.csv")
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
Dingling_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Dingling_20130301-20170228.csv")
Dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
Dongsi_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Dongsi_20130301-20170228.csv")
Dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
Guanyuan_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Guanyuan_20130301-20170228.csv")
Guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
Gucheng_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Gucheng_20130301-20170228.csv")
Gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
Huairou_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Huairou_20130301-20170228.csv")
Huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
Nongzhanguan_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Nongzhanguan_20130301-20170228.csv")
Nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
Shunyi_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Shunyi_20130301-20170228.csv")
Shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
Tiantan_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Tiantan_20130301-20170228.csv")
Tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
Wanliu_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Wanliu_20130301-20170228.csv")
Wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
Wanshouxigong_df = pd.read_csv("https://raw.githubusercontent.com/Arif-0123/Proyek_Analisis_Data/main/Air%20Quality%20Dataset/submision/data/PRSA_Data_Wanshouxigong_20130301-20170228.csv")
Wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel `Aotizhongxin_df`

# %%
Aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# missing value/data kosong

# %%
print("Jumlah duplikasi: ",Aotizhongxin_df.duplicated().sum())
Aotizhongxin_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
Aotizhongxin_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        545
# PM10         633
# SO2          330
# NO2          465
# CO           112
# O3           831
# TEMP         967
# PRES         600
# DEWP         604
# RAIN         127
# wd            16
# WSPM          91
# station        1
# dtype: int64

# %% [markdown]
# menampilkan berapa jumlah nilai berbeda dari isi setiap tabel

# %% [markdown]
# #### Menilai tabel `Changping_df`

# %%
Changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# missing value

# %%
print("Jumlah duplikasi: ",Changping_df.duplicated().sum())
Changping_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %%
Changping_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        481
# PM10         562
# SO2          294
# NO2          459
# CO           115
# O3           886
# TEMP         998
# PRES         592
# DEWP         602
# RAIN         116
# wd            16
# WSPM          95
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Dingling_df`

# %%
Dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# missing value

# %%
print("Jumlah duplikasi: ",Dingling_df.duplicated().sum())
Dingling_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %%
Dingling_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        486
# PM10         554
# SO2          327
# NO2          636
# CO           103
# O3           792
# TEMP         998
# PRES         593
# DEWP         602
# RAIN         116
# wd            16
# WSPM          95
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Dongsi_df`

# %%
Dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Dongsi_df.duplicated().sum())
Dongsi_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %%
Dongsi_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        582
# PM10         666
# SO2          392
# NO2          701
# CO           115
# O3           737
# TEMP         963
# PRES         595
# DEWP         617
# RAIN         119
# wd            16
# WSPM         101
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Guanyuan_df`

# %%
Guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Guanyuan_df.duplicated().sum())
Guanyuan_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %%
Guanyuan_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        557
# PM10         630
# SO2          280
# NO2          376
# CO           117
# O3           767
# TEMP         967
# PRES         600
# DEWP         604
# RAIN         127
# wd            16
# WSPM          91
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Gucheng_df`

# %%
Gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Gucheng_df.duplicated().sum())
Gucheng_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %%
Gucheng_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        577
# PM10         660
# SO2          243
# NO2          367
# CO           116
# O3           804
# TEMP         995
# PRES         592
# DEWP         594
# RAIN         125
# wd            16
# WSPM         101
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Huairou_df`

# %%
Huairou_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Huairou_df.duplicated().sum())
Huairou_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %%
Huairou_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        479
# PM10         556
# SO2          247
# NO2          296
# CO           108
# O3           812
# TEMP        1012
# PRES         589
# DEWP         617
# RAIN         128
# wd            16
# WSPM         105
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Nongzhanguan_df`

# %%
Nongzhanguan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Nongzhanguan_df.duplicated().sum())
Nongzhanguan_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %%
Nongzhanguan_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        565
# PM10         649
# SO2          263
# NO2          595
# CO           115
# O3           732
# TEMP         963
# PRES         595
# DEWP         617
# RAIN         119
# wd            16
# WSPM         101
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Shunyi_df`

# %%
Shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Shunyi_df.duplicated().sum())
Shunyi_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %%
Shunyi_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        567
# PM10         605
# SO2          267
# NO2          517
# CO           115
# O3           961
# TEMP         985
# PRES         602
# DEWP         608
# RAIN         120
# wd            16
# WSPM         103
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Tiantan_df`

# %%
Tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Tiantan_df.duplicated().sum())
Tiantan_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %%
Tiantan_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        545
# PM10         640
# SO2          259
# NO2          319
# CO           117
# O3           678
# TEMP         963
# PRES         595
# DEWP         617
# RAIN         119
# wd            16
# WSPM         101
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Wanliu_df`

# %%
Wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Wanliu_df.duplicated().sum())
Wanliu_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %%
Wanliu_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        539
# PM10         616
# SO2          460
# NO2          958
# CO           120
# O3           734
# TEMP         971
# PRES         593
# DEWP         600
# RAIN         125
# wd            16
# WSPM          86
# station        1
# dtype: int64

# %% [markdown]
# #### Menilai tabel `Wanshouxigong_df`

# %%
Wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",Wanshouxigong_df.duplicated().sum())
Wanshouxigong_df.describe()
# Out:
# Jumlah duplikasi:  0
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %%
Wanshouxigong_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        585
# PM10         648
# SO2          279
# NO2          422
# CO           116
# O3           716
# TEMP         965
# PRES         607
# DEWP         608
# RAIN         121
# wd            16
# WSPM          96
# station        1
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# 1. Memperbaiki missing value pada setiap tabel dengan mengantikannya dengan nilai mean dan nilai terbanyak

# %% [markdown]
# #### Membersihkan tabel `Aotizhongxin_df`

# %%
Aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Aotizhongxin_df["PM2.5"].mean()
Aotizhongxin_df["PM2.5"] = Aotizhongxin_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["PM10"].mean()
Aotizhongxin_df["PM10"] = Aotizhongxin_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["SO2"].mean()
Aotizhongxin_df["SO2"] = Aotizhongxin_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["NO2"].mean()
Aotizhongxin_df["NO2"] = Aotizhongxin_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["CO"].mean()
Aotizhongxin_df["CO"] = Aotizhongxin_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["O3"].mean()
Aotizhongxin_df["O3"] = Aotizhongxin_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["TEMP"].mean()
Aotizhongxin_df["TEMP"] = Aotizhongxin_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["PRES"].mean()
Aotizhongxin_df["PRES"] = Aotizhongxin_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["DEWP"].mean()
Aotizhongxin_df["DEWP"] = Aotizhongxin_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["RAIN"].mean()
Aotizhongxin_df["RAIN"] = Aotizhongxin_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Aotizhongxin_df["WSPM"].mean()
Aotizhongxin_df["WSPM"] = Aotizhongxin_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         81
# WSPM        0
# station     0
# dtype: int64

# %%
Aotizhongxin_df.wd.value_counts()
# Out:
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Aotizhongxin_df['wd'].fillna(value='NE', inplace=True)

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Changping_df`

# %%
Changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Changping_df["PM2.5"].mean()
Changping_df["PM2.5"] = Changping_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["PM10"].mean()
Changping_df["PM10"] = Changping_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["SO2"].mean()
Changping_df["SO2"] = Changping_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["NO2"].mean()
Changping_df["NO2"] = Changping_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["CO"].mean()
Changping_df["CO"] = Changping_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["O3"].mean()
Changping_df["O3"] = Changping_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["TEMP"].mean()
Changping_df["TEMP"] = Changping_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["PRES"].mean()
Changping_df["PRES"] = Changping_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["DEWP"].mean()
Changping_df["DEWP"] = Changping_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["RAIN"].mean()
Changping_df["RAIN"] = Changping_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Changping_df["WSPM"].mean()
Changping_df["WSPM"] = Changping_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Changping_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         140
# WSPM         0
# station      0
# dtype: int64

# %%
Changping_df.wd.value_counts()
# Out:
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Changping_df['wd'].fillna(value='NNW', inplace=True)

# %%
Changping_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Dingling_df`

# %%
Dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %%
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Dingling_df["PM2.5"].mean()
Dingling_df["PM2.5"] = Dingling_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["PM10"].mean()
Dingling_df["PM10"] = Dingling_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["SO2"].mean()
Dingling_df["SO2"] = Dingling_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["NO2"].mean()
Dingling_df["NO2"] = Dingling_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["CO"].mean()
Dingling_df["CO"] = Dingling_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["O3"].mean()
Dingling_df["O3"] = Dingling_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["TEMP"].mean()
Dingling_df["TEMP"] = Dingling_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["PRES"].mean()
Dingling_df["PRES"] = Dingling_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["DEWP"].mean()
Dingling_df["DEWP"] = Dingling_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["RAIN"].mean()
Dingling_df["RAIN"] = Dingling_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dingling_df["WSPM"].mean()
Dingling_df["WSPM"] = Dingling_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Dingling_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         140
# WSPM         0
# station      0
# dtype: int64

# %%
Dingling_df.wd.value_counts()
# Out:
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Dingling_df['wd'].fillna(value='NNW', inplace=True)

# %%
Dingling_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Dongsi_df`

# %%
Dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %%
Dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Dongsi_df["PM2.5"].mean()
Dongsi_df["PM2.5"] = Dongsi_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["PM10"].mean()
Dongsi_df["PM10"] = Dongsi_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["SO2"].mean()
Dongsi_df["SO2"] = Dongsi_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["NO2"].mean()
Dongsi_df["NO2"] = Dongsi_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["CO"].mean()
Dongsi_df["CO"] = Dongsi_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["O3"].mean()
Dongsi_df["O3"] = Dongsi_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["TEMP"].mean()
Dongsi_df["TEMP"] = Dongsi_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["PRES"].mean()
Dongsi_df["PRES"] = Dongsi_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["DEWP"].mean()
Dongsi_df["DEWP"] = Dongsi_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["RAIN"].mean()
Dongsi_df["RAIN"] = Dongsi_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Dongsi_df["WSPM"].mean()
Dongsi_df["WSPM"] = Dongsi_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Dongsi_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %%
Dongsi_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Dongsi_df['wd'].fillna(value='ENE', inplace=True)

# %%
Dongsi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Guanyuan_df`

# %%
Guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %%
Guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Guanyuan_df["PM2.5"].mean()
Guanyuan_df["PM2.5"] = Guanyuan_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["PM10"].mean()
Guanyuan_df["PM10"] = Guanyuan_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["SO2"].mean()
Guanyuan_df["SO2"] = Guanyuan_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["NO2"].mean()
Guanyuan_df["NO2"] = Guanyuan_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["CO"].mean()
Guanyuan_df["CO"] = Guanyuan_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["O3"].mean()
Guanyuan_df["O3"] = Guanyuan_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["TEMP"].mean()
Guanyuan_df["TEMP"] = Guanyuan_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["PRES"].mean()
Guanyuan_df["PRES"] = Guanyuan_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["DEWP"].mean()
Guanyuan_df["DEWP"] = Guanyuan_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["RAIN"].mean()
Guanyuan_df["RAIN"] = Guanyuan_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Guanyuan_df["WSPM"].mean()
Guanyuan_df["WSPM"] = Guanyuan_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Guanyuan_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         81
# WSPM        0
# station     0
# dtype: int64

# %%
Guanyuan_df.wd.value_counts()
# Out:
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Guanyuan_df['wd'].fillna(value='NE', inplace=True)

# %%
Guanyuan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Gucheng_df`

# %%
Gucheng_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %%
Gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Gucheng_df["PM2.5"].mean()
Gucheng_df["PM2.5"] = Gucheng_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["PM10"].mean()
Gucheng_df["PM10"] = Gucheng_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["SO2"].mean()
Gucheng_df["SO2"] = Gucheng_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["NO2"].mean()
Gucheng_df["NO2"] = Gucheng_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["CO"].mean()
Gucheng_df["CO"] = Gucheng_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["O3"].mean()
Gucheng_df["O3"] = Gucheng_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["TEMP"].mean()
Gucheng_df["TEMP"] = Gucheng_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["PRES"].mean()
Gucheng_df["PRES"] = Gucheng_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["DEWP"].mean()
Gucheng_df["DEWP"] = Gucheng_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["RAIN"].mean()
Gucheng_df["RAIN"] = Gucheng_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Gucheng_df["WSPM"].mean()
Gucheng_df["WSPM"] = Gucheng_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Gucheng_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         159
# WSPM         0
# station      0
# dtype: int64

# %%
Gucheng_df.wd.value_counts()
# Out:
# N      3949
# NE     3119
# SSW    2762
# NW     2758
# NNE    2602
# S      2343
# W      2331
# WNW    2073
# SW     1993
# ENE    1885
# WSW    1621
# NNW    1614
# E      1607
# SSE    1553
# ESE    1353
# SE     1342
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Gucheng_df['wd'].fillna(value='N', inplace=True)

# %%
Gucheng_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Huairou_df`

# %%
Huairou_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %%
Huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Huairou_df["PM2.5"].mean()
Huairou_df["PM2.5"] = Huairou_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["PM10"].mean()
Huairou_df["PM10"] = Huairou_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["SO2"].mean()
Huairou_df["SO2"] = Huairou_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["NO2"].mean()
Huairou_df["NO2"] = Huairou_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["CO"].mean()
Huairou_df["CO"] = Huairou_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["O3"].mean()
Huairou_df["O3"] = Huairou_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["TEMP"].mean()
Huairou_df["TEMP"] = Huairou_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["PRES"].mean()
Huairou_df["PRES"] = Huairou_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["DEWP"].mean()
Huairou_df["DEWP"] = Huairou_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["RAIN"].mean()
Huairou_df["RAIN"] = Huairou_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Huairou_df["WSPM"].mean()
Huairou_df["WSPM"] = Huairou_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Huairou_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         302
# WSPM         0
# station      0
# dtype: int64

# %%
Huairou_df.wd.value_counts()
# Out:
# NW     4943
# WNW    4876
# NE     2252
# E      2159
# W      2138
# SE     2113
# ENE    2026
# ESE    2022
# SW     1797
# NNE    1687
# NNW    1663
# SSE    1573
# WSW    1468
# N      1367
# SSW    1350
# S      1328
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
perbaiki_missingvalue = Huairou_df["wd"].value_counts().mean()
Huairou_df['wd'] = Huairou_df['wd'].fillna(perbaiki_missingvalue)

# %%
Huairou_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Nongzhanguan_df`

# %%
Nongzhanguan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Nongzhanguan_df["PM2.5"].mean()
Nongzhanguan_df["PM2.5"] = Nongzhanguan_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["PM10"].mean()
Nongzhanguan_df["PM10"] = Nongzhanguan_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["SO2"].mean()
Nongzhanguan_df["SO2"] = Nongzhanguan_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["NO2"].mean()
Nongzhanguan_df["NO2"] = Nongzhanguan_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["CO"].mean()
Nongzhanguan_df["CO"] = Nongzhanguan_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["O3"].mean()
Nongzhanguan_df["O3"] = Nongzhanguan_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["TEMP"].mean()
Nongzhanguan_df["TEMP"] = Nongzhanguan_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["PRES"].mean()
Nongzhanguan_df["PRES"] = Nongzhanguan_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["DEWP"].mean()
Nongzhanguan_df["DEWP"] = Nongzhanguan_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["RAIN"].mean()
Nongzhanguan_df["RAIN"] = Nongzhanguan_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Nongzhanguan_df["WSPM"].mean()
Nongzhanguan_df["WSPM"] = Nongzhanguan_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %%
Nongzhanguan_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Nongzhanguan_df['wd'].fillna(value='ENE', inplace=True)

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Shunyi_df`

# %%
Shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %%
Shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Shunyi_df["PM2.5"].mean()
Shunyi_df["PM2.5"] = Shunyi_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["PM10"].mean()
Shunyi_df["PM10"] = Shunyi_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["SO2"].mean()
Shunyi_df["SO2"] = Shunyi_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["NO2"].mean()
Shunyi_df["NO2"] = Shunyi_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["CO"].mean()
Shunyi_df["CO"] = Shunyi_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["O3"].mean()
Shunyi_df["O3"] = Shunyi_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["TEMP"].mean()
Shunyi_df["TEMP"] = Shunyi_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["PRES"].mean()
Shunyi_df["PRES"] = Shunyi_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["DEWP"].mean()
Shunyi_df["DEWP"] = Shunyi_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["RAIN"].mean()
Shunyi_df["RAIN"] = Shunyi_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Shunyi_df["WSPM"].mean()
Shunyi_df["WSPM"] = Shunyi_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Shunyi_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         483
# WSPM         0
# station      0
# dtype: int64

# %%
Shunyi_df.wd.value_counts()
# Out:
# NNE    4540
# N      3877
# NE     3351
# SSE    2963
# SE     2665
# S      2613
# NW     2446
# WNW    2051
# NNW    1656
# SSW    1586
# ENE    1416
# ESE    1377
# W      1177
# E      1153
# SW      973
# WSW     737
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Shunyi_df['wd'].fillna(value='NNE', inplace=True)

# %%
Shunyi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
Shunyi_df.wd.value_counts()
# Out:
# NNE    5023
# N      3877
# NE     3351
# SSE    2963
# SE     2665
# S      2613
# NW     2446
# WNW    2051
# NNW    1656
# SSW    1586
# ENE    1416
# ESE    1377
# W      1177
# E      1153
# SW      973
# WSW     737
# Name: wd, dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Tiantan_df`

# %%
Tiantan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %%
Tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Tiantan_df["PM2.5"].mean()
Tiantan_df["PM2.5"] = Tiantan_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["PM10"].mean()
Tiantan_df["PM10"] = Tiantan_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["SO2"].mean()
Tiantan_df["SO2"] = Tiantan_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["NO2"].mean()
Tiantan_df["NO2"] = Tiantan_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["CO"].mean()
Tiantan_df["CO"] = Tiantan_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["O3"].mean()
Tiantan_df["O3"] = Tiantan_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["TEMP"].mean()
Tiantan_df["TEMP"] = Tiantan_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["PRES"].mean()
Tiantan_df["PRES"] = Tiantan_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["DEWP"].mean()
Tiantan_df["DEWP"] = Tiantan_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["RAIN"].mean()
Tiantan_df["RAIN"] = Tiantan_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Tiantan_df["WSPM"].mean()
Tiantan_df["WSPM"] = Tiantan_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Tiantan_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %%
Tiantan_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Tiantan_df['wd'].fillna(value='ENE', inplace=True)

# %%
Tiantan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Wanliu_df`

# %%
Wanliu_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %%
Wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Wanliu_df["PM2.5"].mean()
Wanliu_df["PM2.5"] = Wanliu_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["PM10"].mean()
Wanliu_df["PM10"] = Wanliu_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["SO2"].mean()
Wanliu_df["SO2"] = Wanliu_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["NO2"].mean()
Wanliu_df["NO2"] = Wanliu_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["CO"].mean()
Wanliu_df["CO"] = Wanliu_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["O3"].mean()
Wanliu_df["O3"] = Wanliu_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["TEMP"].mean()
Wanliu_df["TEMP"] = Wanliu_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["PRES"].mean()
Wanliu_df["PRES"] = Wanliu_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["DEWP"].mean()
Wanliu_df["DEWP"] = Wanliu_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["RAIN"].mean()
Wanliu_df["RAIN"] = Wanliu_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanliu_df["WSPM"].mean()
Wanliu_df["WSPM"] = Wanliu_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Wanliu_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         123
# WSPM         0
# station      0
# dtype: int64

# %%
Wanliu_df.wd.value_counts()
# Out:
# NE     6703
# SW     4644
# ENE    3642
# NNE    3327
# N      3219
# WSW    2529
# SSW    2101
# NNW    1397
# W      1335
# E      1264
# NW     1107
# S       966
# WNW     813
# SE      707
# SSE     615
# ESE     572
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Wanliu_df['wd'].fillna(value='NE', inplace=True)

# %%
Wanliu_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
Wanliu_df.wd.value_counts()
# Out:
# NE     6826
# SW     4644
# ENE    3642
# NNE    3327
# N      3219
# WSW    2529
# SSW    2101
# NNW    1397
# W      1335
# E      1264
# NW     1107
# S       966
# WNW     813
# SE      707
# SSE     615
# ESE     572
# Name: wd, dtype: int64

# %% [markdown]
# #### Membersihkan tabel `Wanshouxigong_df`

# %%
Wanshouxigong_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %% [markdown]
# Perbaiki missing value dengan mengisi data mean

# %%
perbaiki_missingvalue = Wanshouxigong_df["PM2.5"].mean()
Wanshouxigong_df["PM2.5"] = Wanshouxigong_df["PM2.5"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["PM10"].mean()
Wanshouxigong_df["PM10"] = Wanshouxigong_df["PM10"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["SO2"].mean()
Wanshouxigong_df["SO2"] = Wanshouxigong_df["SO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["NO2"].mean()
Wanshouxigong_df["NO2"] = Wanshouxigong_df["NO2"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["CO"].mean()
Wanshouxigong_df["CO"] = Wanshouxigong_df["CO"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["O3"].mean()
Wanshouxigong_df["O3"] = Wanshouxigong_df["O3"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["TEMP"].mean()
Wanshouxigong_df["TEMP"] = Wanshouxigong_df["TEMP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["PRES"].mean()
Wanshouxigong_df["PRES"] = Wanshouxigong_df["PRES"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["DEWP"].mean()
Wanshouxigong_df["DEWP"] = Wanshouxigong_df["DEWP"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["RAIN"].mean()
Wanshouxigong_df["RAIN"] = Wanshouxigong_df["RAIN"].fillna(perbaiki_missingvalue)

# %%
perbaiki_missingvalue = Wanshouxigong_df["WSPM"].mean()
Wanshouxigong_df["WSPM"] = Wanshouxigong_df["WSPM"].fillna(perbaiki_missingvalue)

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         79
# WSPM        0
# station     0
# dtype: int64

# %%
Wanshouxigong_df.wd.value_counts()
# Out:
# NE     3568
# SW     3428
# ENE    3080
# E      2807
# WNW    2565
# NW     2552
# WSW    2546
# W      2464
# SSW    2457
# ESE    1772
# NNE    1564
# S      1506
# SE     1279
# NNW    1187
# N      1176
# SSE    1034
# Name: wd, dtype: int64

# %% [markdown]
# Perbaiki missing value type data object/string

# %%
Wanshouxigong_df['wd'].fillna(value='NE', inplace=True)

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# kita akan mengukur kualitas udara dari paramater PM2.5,PM10, SO2, NO2, CO, dan O3.
# yang dimana parameter tersebut dibagi menjadi 2 kelompok yaitu :
#
#
# *   ukuran partikel = PM2.5 & PM10
# *   polutan gas = SO2, NO2, CO, dan O3

# %% [markdown]
# ### Explore `Aotizhongxin_df`

# %%
Aotizhongxin_df.sample()
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 21648  21649  2015      8   20     0   31.0  31.0  2.0  37.0  600.0  82.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 21648  22.5  1006.9  16.5   0.0  NNE   1.8  Aotizhongxin

# %%
Aotizhongxin_df.describe(include='all')
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
Aotizhongxin_df.groupby(by=["year"]).agg({
    "No":"nunique","PM2.5":["max","min","mean","std"],"PM10":["max","min","mean","std"]
})
# Out:
#           No  PM2.5                               PM10                   \
#      nunique    max  min       mean         std    max  min        mean
# year
# 2013    7344  665.0  3.0  82.393043   73.615581  844.0  2.0  112.913167
# 2014    8760  584.0  3.0  90.333581   80.546945  948.0  3.0  121.389921
# 2015    8760  657.0  3.0  82.134578   84.553837  984.0  3.0  112.035381
# 2016    8784  898.0  3.0  74.279022   76.406974  884.0  4.0   94.842749
# 2017    1416  713.0  3.0  94.626679  114.185700  858.0  3.0  107.357984
#
#
#              std
# year
# 2013   84.444642
# 2014   97.732866
# 2015   99.496291
# 2016   86.545418
# 2017  117.802626

# %%
Aotizhongxin_df.groupby(by=["year"]).agg({
    "No":"nunique","SO2":["max","min","mean","std"],"NO2":["max","min","mean","std"],"O3":["max","min","mean","std"]
})
# Out:
#           No    SO2                                  NO2                  \
#      nunique    max     min       mean        std    max  min       mean
# year
# 2013    7344  186.0  0.2856  23.493029  25.649358  228.0  2.0  63.390231
# 2014    8760  197.0  2.0000  21.097476  27.631039  285.0  2.0  63.742087
# 2015    8760  161.0  2.0000  14.407922  17.967516  290.0  2.0  60.937350
# 2016    8784  341.0  2.0000  10.959400  14.955762  218.0  2.0  48.725888
# 2017    1416  164.0  2.0000  20.791767  20.849319  217.0  2.0  66.215968
#
#                        O3
#             std       max     min       mean        std
# year
# 2013  33.218328  358.9992  0.2142  50.221417  51.969223
# 2014  35.707724  338.0000  1.0000  49.941810  53.848301
# 2015  38.996393  423.0000  2.0000  63.748528  61.032145
# 2016  33.856373  350.0000  2.0000  61.914457  59.451523
# 2017  45.009119  133.0000  2.0000  47.573536  32.009289

# %% [markdown]
# ### Explore `Changping_df`

# %% [markdown]
# ### Explore `Dingling_df`

# %% [markdown]
# ### Explore `Dongsi_df`

# %% [markdown]
# ### Explore `Guanyuan_df`

# %% [markdown]
# ### Explore `Gucheng_df`

# %% [markdown]
# ### Explore `Huairou_df`

# %% [markdown]
# ### Explore `Nongzhanguan_df`

# %% [markdown]
# ### Explore `Shunyi_df`

# %% [markdown]
# ### Explore `Tiantan_df`

# %% [markdown]
# ### Explore `Wanliu_df`

# %% [markdown]
# ### Explore `Wanshouxigong_df`

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# 1.   Bagaimana rata-rata kualitas udara disetiap station dalam beberapa tahun terakhir?
# 2.   station manakah rata-rata kualitas udara terbaik dan terburuk berada?

# %% [markdown]
# ### Pertanyaan 1: Bagaimana rata-rata kualitas udara disetiap station dalam beberapa tahun terakhir?

# %% [markdown]
# ### Pertanyaan 2: station manakah rata-rata kualitas udara terbaik dan terburuk berada?

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - conclution pertanyaan 2
